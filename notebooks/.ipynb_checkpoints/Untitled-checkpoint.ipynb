# %%
# import Class
from classy import Class
import numpy as np
# to get plots displayed in notebook
# %matplotlib notebook
import matplotlib.pyplot as plt
from math import pi
# get all data points 
# first, check LCDM model
Pk_lcdm = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_ext_pk.dat")[:,1]
kk_lcdm = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_ext_pk.dat")[:,0]
Pk_lcdm_no = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_ext_no_pk.dat")[:,1]
kk_lcdm_no = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_ext_no_pk.dat")[:,0]
Pk_d = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_ext_pk.dat")[:,1]
kk_d = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_ext_pk.dat")[:,0]
Pk_d_no = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_ext_no_pk.dat")[:,1]
kk_d_no = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_ext_no_pk.dat")[:,0]

lcdm_interp = np.interp(kk_d, kk_lcdm, Pk_lcdm)
lcdm_new = Pk_d - lcdm_interp
lcdm_i = np.interp(kk_d_no, kk_lcdm_no, Pk_lcdm)
lcdm_n = Pk_d_no - lcdm_i

plt.figure()
plt.xscale('log');plt.yscale('log')
plt.plot(kk_lcdm_no,Pk_lcdm_no, 'r-')
plt.plot(kk_lcdm,Pk_lcdm, 'k--')
plt.plot(kk_d_no,Pk_d_no, 'g-')
plt.plot(kk_d, Pk_d,'y--' )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xscale("log")
plt.xlim(1.0e-5,10.)
plt.plot(kk_d, lcdm_new/lcdm_interp,'k--' )
plt.plot(kk_d_no, lcdm_n/lcdm_i,'r-' )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
len(kk_d)
# Out:
# 698

# %%
kk_d[0]
# Out:
# 1.052808673426e-05
