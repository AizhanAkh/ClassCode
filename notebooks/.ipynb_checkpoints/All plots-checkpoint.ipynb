# %%
# import Class
from classy import Class
import numpy as np
# to get plots displayed in notebook
# %matplotlib notebook
import matplotlib.pyplot as plt
from math import pi

# %%
# first, output all the plots
# like ./class test_lcdm.ini
# then get all the necessary values ClTT, ClPP, Pk

# first, check LCDM model
# plot P(k)
plt.figure(1)
plt.xscale('log');plt.yscale('log')
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_lcdm,Pk_lcdm,'b-')
plt.show()

# plot C_l^TT
plt.figure(2)
plt.xscale('linear');plt.yscale('linear');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{TT}$')
plt.plot(ll_lcdm,clTT_lcdm,'b-')
plt.show()

# plot C_l^PP
plt.figure(3)
plt.xscale('log');plt.yscale('log');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{\Phi\Phi}$')
plt.plot(ll_lcdm,clPP_lcdm,'r-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# check Dmeff model w/ n= 0
Pk_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_pk.dat")[:,1]
kk_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_pk.dat")[:,0]
ll_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_cl_lensed.dat")[:,0]
clTT_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_cl_lensed.dat")[:,1]
clPP_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_cl_lensed.dat")[:,5]
# plot P(k)
plt.figure()
plt.xscale('log');plt.yscale('log')
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_dmeff_0,Pk_dmeff_0,'b-')
plt.show()
# plot C_l^TT
plt.figure()
plt.xscale('linear');plt.yscale('linear');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{TT}$')
plt.plot(ll_dmeff_0,clTT_dmeff_0,'b-')
plt.show()

# plot C_l^PP
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{\Phi\Phi}$')
plt.plot(ll_dmeff_0,clPP_dmeff_0,'r-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# check Dmeff model w/ n= 2
Pk_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_pk.dat")[:,1]
kk_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_pk.dat")[:,0]
ll_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_cl_lensed.dat")[:,0]
clTT_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_cl_lensed.dat")[:,1]
clPP_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_cl_lensed.dat")[:,5]
# plot P(k)
plt.figure()
plt.xscale('log');plt.yscale('log')
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_dmeff_2,Pk_dmeff_2,'b-')
plt.show()
# plot C_l^TT
plt.figure()
plt.xscale('linear');plt.yscale('linear');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{TT}$')
plt.plot(ll_dmeff_2,clTT_dmeff_2,'b-')
plt.show()
# plot C_l^PP
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{\Phi\Phi}$')
plt.plot(ll_dmeff_2,clPP_dmeff_2,'r-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# check Dmeff model w/ n= -2
Pk_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_pk.dat")[:,1]
kk_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_pk.dat")[:,0]
ll_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_cl_lensed.dat")[:,0]
clTT_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_cl_lensed.dat")[:,1]
clPP_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_cl_lensed.dat")[:,5]
# plot P(k)
plt.figure()
plt.xscale('log');plt.yscale('log')
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_dmeff__2,Pk_dmeff__2,'b-')
plt.show()
# plot C_l^TT
plt.figure()
plt.xscale('linear');plt.yscale('linear');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{TT}$')
plt.plot(ll_dmeff__2,clTT_dmeff__2,'b-')
plt.show()
# plot C_l^PP
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{\Phi\Phi}$')
plt.plot(ll_dmeff__2,clPP_dmeff__2,'r-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# get all data points 
# first, check LCDM model
Pk_lcdm = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_pk.dat")[:,1]
kk_lcdm = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_pk.dat")[:,0]
ll_lcdm = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_cl_lensed.dat")[:,0]
clTT_lcdm = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_cl_lensed.dat")[:,1]
clPP_lcdm = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= 0
Pk_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_pk.dat")[:,1]
kk_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_pk.dat")[:,0]
ll_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_cl_lensed.dat")[:,0]
clTT_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_cl_lensed.dat")[:,1]
clPP_dmeff_0 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= 2
Pk_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_pk.dat")[:,1]
kk_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_pk.dat")[:,0]
ll_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_cl_lensed.dat")[:,0]
clTT_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_cl_lensed.dat")[:,1]
clPP_dmeff_2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= -2
Pk_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_pk.dat")[:,1]
kk_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_pk.dat")[:,0]
ll_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_cl_lensed.dat")[:,0]
clTT_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_cl_lensed.dat")[:,1]
clPP_dmeff__2 = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_cl_lensed.dat")[:,5]

# %%
# get all data points for HALOFIT
# first, check LCDM model
Pk_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_halofit_pk.dat")[:,1]
kk_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_halofit_pk.dat")[:,0]
ll_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_halofit_cl_lensed.dat")[:,0]
clTT_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_halofit_cl_lensed.dat")[:,1]
clPP_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_halofit_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= 0
Pk_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_halofit_pk.dat")[:,1]
kk_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_halofit_pk.dat")[:,0]
ll_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_halofit_cl_lensed.dat")[:,0]
clTT_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_halofit_cl_lensed.dat")[:,1]
clPP_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_0_halofit_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= 2
Pk_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_halofit_pk.dat")[:,1]
kk_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_halofit_pk.dat")[:,0]
ll_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_halofit_cl_lensed.dat")[:,0]
clTT_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_halofit_cl_lensed.dat")[:,1]
clPP_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_2_halofit_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= -2
Pk_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_halofit_pk.dat")[:,1]
kk_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_halofit_pk.dat")[:,0]
ll_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_halofit_cl_lensed.dat")[:,0]
clTT_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_halofit_cl_lensed.dat")[:,1]
clPP_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/dmeff_-2_halofit_cl_lensed.dat")[:,5]

# %%
# get all data points for HALOFIT
# new FILES in OUTPUT
# first, check LCDM model
Pk_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/lcdm_halofit_pk.dat")[:,1]
kk_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/lcdm_halofit_pk.dat")[:,0]
ll_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/lcdm_halofit_cl_lensed.dat")[:,0]
clTT_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/lcdm_halofit_cl_lensed.dat")[:,1]
clPP_lcdm_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/lcdm_halofit_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= 0
Pk_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_0_halofit_pk.dat")[:,1]
kk_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_0_halofit_pk.dat")[:,0]
ll_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_0_halofit_cl_lensed.dat")[:,0]
clTT_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_0_halofit_cl_lensed.dat")[:,1]
clPP_dmeff_0_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_0_halofit_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= 2
Pk_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_2_halofit_pk.dat")[:,1]
kk_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_2_halofit_pk.dat")[:,0]
ll_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_2_halofit_cl_lensed.dat")[:,0]
clTT_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_2_halofit_cl_lensed.dat")[:,1]
clPP_dmeff_2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_2_halofit_cl_lensed.dat")[:,5]
# check Dmeff model w/ n= -2
Pk_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_-2_halofit_pk.dat")[:,1]
kk_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_-2_halofit_pk.dat")[:,0]
ll_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_-2_halofit_cl_lensed.dat")[:,0]
clTT_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_-2_halofit_cl_lensed.dat")[:,1]
clPP_dmeff__2_h = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/class/output/dmeff_-2_halofit_cl_lensed.dat")[:,5]

# %%
# get all data for EFT 
# load corrections to Pk
lcdm_c = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/code/lcdm_P_1loop.dat")
dmeff0_c = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/code/dmeff_0_P_1loop.dat")
dmeff2_c = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/code/dmeff_2_P_1loop.dat")
dmeff_2_c = np.genfromtxt("/Users/aizhan.akh/Documents/Projects/PT-check/code/dmeff_-2_P_1loop.dat")
kk = lcdm_c[:, 0]
Pk = lcdm_c[:, 1]
kk1 = dmeff0_c[:, 0]
Pk1 = dmeff0_c[:, 1]
kk2 = dmeff2_c[:, 0]
Pk2 = dmeff2_c[:, 1]
kk3 = dmeff_2_c[:,0]
Pk3 = dmeff_2_c[:,1]

# %%
# get all the residuals
# first, NO HALOFIT
# residuals
res_clTT0 = (clTT_dmeff_0 - clTT_lcdm)/clTT_lcdm
res_clTT2 = (clTT_dmeff_2 - clTT_lcdm)/clTT_lcdm
res_clTT_2 = (clTT_dmeff__2 - clTT_lcdm)/clTT_lcdm

res_clPP0 = (clPP_dmeff_0 - clPP_lcdm)/clPP_lcdm
res_clPP2 = (clPP_dmeff_2 - clPP_lcdm)/clPP_lcdm
res_clPP_2 = (clPP_dmeff__2 - clPP_lcdm)/clPP_lcdm

res_Pk0 = (Pk_dmeff_0 - Pk_lcdm)/Pk_lcdm
res_Pk2 = (Pk_dmeff_2 - Pk_lcdm)/Pk_lcdm
res_Pk_2 = (Pk_dmeff__2 - Pk_lcdm)/Pk_lcdm

# WITH HALOFIT
# residuals
res_clTT0_h = (clTT_dmeff_0_h - clTT_lcdm_h)/clTT_lcdm_h
res_clTT2_h = (clTT_dmeff_2_h - clTT_lcdm_h)/clTT_lcdm_h
res_clTT_2_h = (clTT_dmeff__2 - clTT_lcdm_h)/clTT_lcdm_h

res_clPP0_h = (clPP_dmeff_0_h - clPP_lcdm_h)/clPP_lcdm_h
res_clPP2_h = (clPP_dmeff_2_h - clPP_lcdm_h)/clPP_lcdm_h
res_clPP_2_h = (clPP_dmeff__2_h - clPP_lcdm_h)/clPP_lcdm_h

res_Pk0_h = (Pk_dmeff_0_h - Pk_lcdm_h)/Pk_lcdm_h
res_Pk2_h = (Pk_dmeff_2_h - Pk_lcdm_h)/Pk_lcdm_h
res_Pk_2_h = (Pk_dmeff__2_h - Pk_lcdm_h)/Pk_lcdm_h

# %%
# now get spectra with EFT CORRECTIONS

# we want to add Pk to lcdm values which correspond to particular kk values
# so we need to interpolte lcdm values for those particular values of kk
lcdm_interp = np.interp(kk, kk_lcdm, Pk_lcdm)
lcdm_new = Pk + lcdm_interp

# same interpolation with dmeff sets
dmeff0_interp = np.interp(kk1, kk_dmeff_0, Pk_dmeff_0)
dmeff0_new = Pk1 + dmeff0_interp

dmeff2_interp = np.interp(kk2, kk_dmeff_2, Pk_dmeff_2)
dmeff2_new = Pk2 + dmeff2_interp

dmeff_2_interp = np.interp(kk3, kk_dmeff__2, Pk_dmeff__2)
dmeff_2_new = Pk3 + dmeff_2_interp

# calculate residuals
#lcdm_new1 = np.interp(kk1, kk_lcdm, lcdm_new) - BAD interpolation
res_new1 = (dmeff0_new-lcdm_new)/lcdm_new

#lcdm_new2 = np.interp(kk2, kk_lcdm, lcdm_new)
res_new2 = (dmeff2_new-lcdm_new)/lcdm_new

#lcdm_new3 = np.interp(kk3, kk_lcdm, lcdm_new)
res_new3 = (dmeff_2_new-lcdm_new)/lcdm_new

# %%
# plot all the Pk plots


#plot HALOFIT VS NO HALOFIT
plt.figure()
plt.xscale('log');plt.yscale('log')
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_lcdm,Pk_lcdm,'k-', label = "LCDM")
plt.plot(kk_dmeff_0,Pk_dmeff_0,'g-', label = 'n = 0')
plt.plot(kk_dmeff_2,Pk_dmeff_2,'r-', label = 'n = 2')
plt.plot(kk_dmeff__2,Pk_dmeff__2,'b-', label = 'n = -2')
plt.plot(kk_lcdm_h,Pk_lcdm_h,'r--', label = "LCDM w/ halofit")
plt.plot(kk_dmeff_0_h,Pk_dmeff_0_h,'m--', label = 'n = 0 w/ halofit')
plt.plot(kk_dmeff_2_h,Pk_dmeff_2_h,'b--', label = 'n = 2 w/ halofit')
plt.plot(kk_dmeff__2_h,Pk_dmeff__2_h,'y--', label = 'n = -2 w/ halofit')
plt.legend(loc = "lower left")
plt.title("HALOFIT VS LINEAR")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xscale('log');plt.yscale('log')
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_lcdm,Pk_lcdm,'k-', label = "LCDM")
plt.plot(kk_dmeff_0,Pk_dmeff_0,'g-', label = 'n = 0')
plt.plot(kk_dmeff_2,Pk_dmeff_2,'r-', label = 'n = 2')
plt.plot(kk_dmeff__2,Pk_dmeff__2,'b-', label = 'n = -2')
plt.plot(kk, lcdm_new, 'k--',label = "LCDM, EFT")
plt.plot(kk1, dmeff0_new, 'g--',label = "n = 0, EFT")
plt.plot(kk2, dmeff2_new,'r--', label = "n = 2, EFT")
plt.plot(kk3, dmeff_2_new,'b--', label = "n = -2, EFT")

plt.legend(loc = "lower left")
plt.title("EFT CORRECTIONS VS LINEAR")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#plot Pk 
plt.figure()
plt.xscale('log');plt.yscale('linear');plt.xlim(kk[0],kk[-1]) # the region where Pk starts to diverge noticeably - can change to [0] to [-1]
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$(P(k)(\sigma_0) - P(k)(\lambda CDM))\,/\, P(k)(\lambda CDM)  \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_lcdm_h,res_Pk0_h,'b-', label = "n = 0, w/ halofit")
plt.plot(kk_lcdm_h,res_Pk2_h,'g-', label = "n = 2, w/ halofit")
plt.plot(kk_dmeff__2_h,res_Pk_2_h,'k-', label = "n = -2, w/ halofit")
plt.plot(kk1, res_new1, 'g-',label = "n = 0, EFT")
plt.plot(kk2, res_new2,'r--', label = "n = 2, EFT")
plt.plot(kk3, res_new3,'b--', label = "n = -2, EFT")
plt.title("Pk RESIDUAL SPECTRA")
plt.legend(loc ="lower left")
plt.show()
#plt.savefig("Plots/m_1GeV_n_02-2resPk_halofit.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xscale('log');plt.yscale('linear');plt.xlim(1.e-5,10.0) # the region where Pk starts to diverge noticeably - can change to [0] to [-1]
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$(P(k)(\sigma_0) - P(k)(\lambda CDM))\,/\, P(k)(\lambda CDM)  \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk1, res_new1, 'g-',label = "n = 0, EFT")
plt.plot(kk2, res_new2,'r--', label = "n = 2, EFT")
plt.plot(kk3, res_new3,'b--', label = "n = -2, EFT")
plt.legend(loc ="upper left")
plt.title("Pk RESIDUAL SPECTRA: EFT ONLY")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-1,1.);plt.ylim(1.0e3, 1.0e5) # the region where Pk starts to diverge noticeably - can change to [0] to [-1]
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$(P(k)(\sigma_0) - P(k)(\lambda CDM))\,/\, P(k)(\lambda CDM)  \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk1, dmeff0_new, 'g-',label = "n = 0, EFT")
plt.plot(kk2, dmeff2_new,'r--', label = "n = 2, EFT")
plt.plot(kk3, dmeff_2_new,'b--', label = "n = -2, EFT")
plt.plot(kk, lcdm_new,'k--', label = "LCDM, EFT")
plt.legend(loc ="upper left")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot the residuals
# plot C_l^TT residual power spectra
plt.figure()
plt.xscale('linear');plt.yscale('linear');plt.xlim(0,2500)
plt.title(r"$m \ deff = 1 GeV,\, \Omega_{DM} = 0.1205$")
plt.xlabel(r'$\ell$')
plt.ylabel(r'$ (C_\ell^\mathrm{TT}(\sigma_0) - C_\ell^\mathrm{TT}(\lambda CDM))/C_\ell^\mathrm{TT}(\lambda CDM))$')
# !! need to scale by l(l+1)/(2pi)
plt.plot(ll_lcdm_h,res_clTT0_h,'b-', label = "n = 0, w/ halofit")
plt.plot(ll_lcdm_h,res_clTT2_h,'g-', label = "n = 2, w/ halofit")
plt.plot(ll_lcdm_h,res_clTT_2_h,'k-', label = "n = -2, w/ halofit")
plt.plot(ll_lcdm,res_clTT0,'b--', label = "n = 0")
plt.plot(ll_lcdm,res_clTT2,'g--', label = "n = 2")
plt.plot(ll_lcdm,res_clTT_2,'k--', label = "n = -2")
plt.legend(loc ="lower left")
plt.show()
#plt.savefig("Plots/m_1GeV_n_02-2resClTT_halofit.png")
    
# plot C_l^PP (I could not find /kappa/kappa)
plt.figure()
plt.xscale('linear');plt.yscale('linear');plt.xlim(0,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$ (C_\ell^\mathrm{\Phi\Phi}(\sigma_0) - C_\ell^\mathrm{\Phi\Phi}(\lambda CDM))/C_\ell^\mathrm{\Phi\Phi}(\lambda CDM))$')
plt.plot(ll_lcdm_h,res_clPP0_h,'b-', label = "n = 0, w/ halofit")
plt.plot(ll_lcdm_h,res_clPP2_h,'g-', label = "n = 2, w/ halofit")
plt.plot(ll_lcdm_h,res_clPP_2_h,'k-', label = "n = -2, w/ halofit")
plt.plot(ll_lcdm,res_clPP0,'b--', label = "n = 0")
plt.plot(ll_lcdm,res_clPP2,'g--', label = "n = 2")
plt.plot(ll_lcdm,res_clPP_2,'k--', label = "n = -2")

plt.legend(loc ="lower left")
plt.title(r"$m \ deff = 1 GeV,\, \Omega_{DM} = 0.1205$")
plt.show()
#plt.savefig("Plots/m_1GeV_n_02-2resClPP_halofit.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
kk1[89]
# Out:
# 5.838810752008942e-05

# %%
kk[89]
# Out:
# 5.838810752008942e-05

# %%
l = np.linspace(1, 681, 681)
plt.figure()
plt.plot(l, kk3-kk)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
