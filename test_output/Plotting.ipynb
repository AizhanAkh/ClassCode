# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
from math import pi

# %%
data = np.genfromtxt('lcdm_cl.dat')
ll = data[:, 0]
clTT = data[:, 1]
clEE = data[:, 2]
clTE = data[:, 3]
clBB = data[:, 4]
clPP = data[:, 5]
clTP = data[:, 6]
clEP = data[:, 7]

# %%
# plot C_l^TT
plt.figure(1)
plt.xscale('linear');plt.yscale('linear');plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$[\ell(\ell+1)/2\pi]  C_\ell^\mathrm{TT}$')
plt.plot(ll,clTT*ll*(ll+1)/2./pi,'r-')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
